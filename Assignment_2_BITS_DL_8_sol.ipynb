# %% [markdown]
# # Develop an image caption generator model using Tensorflow-keras
#
# In this assignment, you will have to train a caption generator model for images. It requires a CNN model to extract the content of images and an RNN model to learn the corresponding captions of the images. These two features are finally merged and trained using dense layers.
#
# The below research papers are for your reference-
# 1. [Where to put the Image in an Image Caption Generator](https://arxiv.org/abs/1703.09137)
# 2. [Framing Image Description as a Ranking Task: Data, Models and Evaluation Metrics](https://www.ijcai.org/Proceedings/15/Papers/593.pdf)
#
# This notebook is divided into six parts. Total : [20 Marks]
#
# 1. Download photo and caption dataset [0 Mark]
# 2. Prepare photo data [2 Marks]
# 3. Prepare text data [4 Marks]
# 4. Develop deep learning model with progressive data loading [8 Marks]
# 5. Evaluate model [4 Marks]
# 6. Generate new captions [2 Marks]

# %%
from IPython.display import Image
Image(filename='Model-Generate-Word-From-Word.jpg')

# %% [markdown]
# # 1. Download photo and caption dataset [0 Mark]

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# !ls -l /gdrive/My\ Drive
root = '/gdrive/My Drive/'
# Out:
# total 853
# -rw------- 1 root root 164256 May 11 19:31  Assignment_2_BITS_DL_8.ipynb
# drwx------ 2 root root   4096 May 12 10:39  Flicker8k_Dataset
# drwx------ 2 root root   4096 May 12 16:27  Flicker8k_Dataset_small
# drwx------ 2 root root   4096 May 12 10:12  Flickr8k_text
# -rw------- 1 root root 696774 Nov 14  2018 'Getting started.pdf'

# %%
ls -l /gdrive/My\ Drive/Flickr8k_text
# Out:
# total 9879
# -rw------- 1 root root 2918552 May 12 10:13 CrowdFlowerAnnotations.txt
# -rw------- 1 root root  346674 Oct 14  2013 ExpertAnnotations.txt
# -rw------- 1 root root   25801 Oct 10  2013 Flickr_8k.devImages.txt
# -rw------- 1 root root 3244761 May 12 10:14 Flickr8k.lemma.token.txt
# -rw------- 1 root root   25775 Oct 10  2013 Flickr_8k.testImages.txt
# -rw------- 1 root root 3395237 Oct 14  2013 Flickr8k.token.txt
# -rw------- 1 root root  154678 Oct 10  2013 Flickr_8k.trainImages.txt
# -rw------- 1 root root    1821 Oct 14  2013 readme.txt

# %%
ls /gdrive/My\ Drive/Flicker8k_Dataset | wc -l
# Out:
# 8096

# %% [markdown]
# # 2. Prepare photo data [1 Mark]

# %%
from os import listdir
from pickle import dump

# You need to import the following functions from tensorflow.keras library
# VGG16, load_img, img_to_array, preprocess_input, Model

#####
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model

# %%
# function to extract features from each photo in the directory
def extract_features(directory):
	# load the VGG16 model
	model = VGG16()

  # Print the model summary to understand the model
	#print(model.summary())

	# re-structure the model by removing the last layer
	#####
	model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
	# summarize
	#print(model.summary())
  
	# extract features from each photo in a dictionary
	features = dict()
	i=0
	# iterate over all the files of the dataset directory
	for name in listdir(directory):
		
		filename = directory + '/' + name

		# load the image from filename with target size of (224,224)
		image = load_img(filename, target_size=(224, 224))
    
		# convert the image pixels to a numpy array
		image = img_to_array(image)

		# reshape data for the model
		image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

		# preprocess the image for the VGG model	
		image = preprocess_input(image)
    
		# get features (output of the model for the image)
		feature = model.predict(image, verbose=0)

		# get image id
		image_id = name.split('.')[0]
		
		# store feature in the features dictionary with image_id as key and feature as value
		features[image_id] = feature
		i = i+1
		print('Features extracted: %d' % i)

	return features

# extract features from all images
directory = root+'Flicker8k_Dataset'
features = extract_features(directory)
print('Extracted Features: %d' % len(features))

# save to file
dump(features, open('features.pkl', 'wb'))
# Out:
# Streaming output truncated to the last 5000 lines.
# Features extracted: 3099
# Features extracted: 3100
# Features extracted: 3101
# Features extracted: 3102
# Features extracted: 3103
# Features extracted: 3104
# Features extracted: 3105
# Features extracted: 3106
# Features extracted: 3107
# Features extracted: 3108
# Features extracted: 3109
# Features extracted: 3110
# Features extracted: 3111
# Features extracted: 3112
# Features extracted: 3113
# Features extracted: 3114
# Features extracted: 3115
# Features extracted: 3116
# Features extracted: 3117
# Features extracted: 3118
# Features extracted: 3119
# Features extracted: 3120
# Features extracted: 3121
# Features extracted: 3122
# Features extracted: 3123
# Features extracted: 3124
# Features extracted: 3125
# Features extracted: 3126
# Features extracted: 3127
# Features extracted: 3128
# Features extracted: 3129
# Features extracted: 3130
# Features extracted: 3131
# Features extracted: 3132
# Features extracted: 3133
# Features extracted: 3134
# Features extracted: 3135
# Features extracted: 3136
# Features extracted: 3137
# Features extracted: 3138
# Features extracted: 3139
# Features extracted: 3140
# Features extracted: 3141
# Features extracted: 3142
# Features extracted: 3143
# Features extracted: 3144
# Features extracted: 3145
# Features extracted: 3146
# Features extracted: 3147
# Features extracted: 3148
# Features extracted: 3149
# Features extracted: 3150
# Features extracted: 3151
# Features extracted: 3152
# Features extracted: 3153
# Features extracted: 3154
# Features extracted: 3155
# Features extracted: 3156
# Features extracted: 3157
# Features extracted: 3158
# Features extracted: 3159
# Features extracted: 3160
# Features extracted: 3161
# Features extracted: 3162
# Features extracted: 3163
# Features extracted: 3164
# Features extracted: 3165
# Features extracted: 3166
# Features extracted: 3167
# Features extracted: 3168
# Features extracted: 3169
# Features extracted: 3170
# Features extracted: 3171
# Features extracted: 3172
# Features extracted: 3173
# Features extracted: 3174
# Features extracted: 3175
# Features extracted: 3176
# Features extracted: 3177
# Features extracted: 3178
# Features extracted: 3179
# Features extracted: 3180
# Features extracted: 3181
# Features extracted: 3182
# Features extracted: 3183
# Features extracted: 3184
# Features extracted: 3185
# Features extracted: 3186
# Features extracted: 3187
# Features extracted: 3188
# Features extracted: 3189
# Features extracted: 3190
# Features extracted: 3191
# Features extracted: 3192
# Features extracted: 3193
# Features extracted: 3194
# Features extracted: 3195
# Features extracted: 3196
# Features extracted: 3197
# Features extracted: 3198
# Features extracted: 3199
# Features extracted: 3200
# Features extracted: 3201
# Features extracted: 3202
# Features extracted: 3203
# Features extracted: 3204
# Features extracted: 3205
# Features extracted: 3206
# Features extracted: 3207
# Features extracted: 3208
# Features extracted: 3209
# Features extracted: 3210
# Features extracted: 3211
# Features extracted: 3212
# Features extracted: 3213
# Features extracted: 3214
# Features extracted: 3215
# Features extracted: 3216
# Features extracted: 3217
# Features extracted: 3218
# Features extracted: 3219
# Features extracted: 3220
# Features extracted: 3221
# Features extracted: 3222
# Features extracted: 3223
# Features extracted: 3224
# Features extracted: 3225
# Features extracted: 3226
# Features extracted: 3227
# Features extracted: 3228
# Features extracted: 3229
# Features extracted: 3230
# Features extracted: 3231
# Features extracted: 3232
# Features extracted: 3233
# Features extracted: 3234
# Features extracted: 3235
# Features extracted: 3236
# Features extracted: 3237
# Features extracted: 3238
# Features extracted: 3239
# Features extracted: 3240
# Features extracted: 3241
# Features extracted: 3242
# Features extracted: 3243
# Features extracted: 3244
# Features extracted: 3245
# Features extracted: 3246
# Features extracted: 3247
# Features extracted: 3248
# Features extracted: 3249
# Features extracted: 3250
# Features extracted: 3251
# Features extracted: 3252
# Features extracted: 3253
# Features extracted: 3254
# Features extracted: 3255
# Features extracted: 3256
# Features extracted: 3257
# Features extracted: 3258
# Features extracted: 3259
# Features extracted: 3260
# Features extracted: 3261
# Features extracted: 3262
# Features extracted: 3263
# Features extracted: 3264
# Features extracted: 3265
# Features extracted: 3266
# Features extracted: 3267
# Features extracted: 3268
# Features extracted: 3269
# Features extracted: 3270
# Features extracted: 3271
# Features extracted: 3272
# Features extracted: 3273
# Features extracted: 3274
# Features extracted: 3275
# Features extracted: 3276
# Features extracted: 3277
# Features extracted: 3278
# Features extracted: 3279
# Features extracted: 3280
# Features extracted: 3281
# Features extracted: 3282
# Features extracted: 3283
# Features extracted: 3284
# Features extracted: 3285
# Features extracted: 3286
# Features extracted: 3287
# Features extracted: 3288
# Features extracted: 3289
# Features extracted: 3290
# Features extracted: 3291
# Features extracted: 3292
# Features extracted: 3293
# Features extracted: 3294
# Features extracted: 3295
# Features extracted: 3296
# Features extracted: 3297
# Features extracted: 3298
# Features extracted: 3299
# Features extracted: 3300
# Features extracted: 3301
# Features extracted: 3302
# Features extracted: 3303
# Features extracted: 3304
# Features extracted: 3305
# Features extracted: 3306
# Features extracted: 3307
# Features extracted: 3308
# Features extracted: 3309
# Features extracted: 3310
# Features extracted: 3311
# Features extracted: 3312
# Features extracted: 3313
# Features extracted: 3314
# Features extracted: 3315
# Features extracted: 3316
# Features extracted: 3317
# Features extracted: 3318
# Features extracted: 3319
# Features extracted: 3320
# Features extracted: 3321
# Features extracted: 3322
# Features extracted: 3323
# Features extracted: 3324
# Features extracted: 3325
# Features extracted: 3326
# Features extracted: 3327
# Features extracted: 3328
# Features extracted: 3329
# Features extracted: 3330
# Features extracted: 3331
# Features extracted: 3332
# Features extracted: 3333
# Features extracted: 3334
# Features extracted: 3335
# Features extracted: 3336
# Features extracted: 3337
# Features extracted: 3338
# Features extracted: 3339
# Features extracted: 3340
# Features extracted: 3341
# Features extracted: 3342
# Features extracted: 3343
# Features extracted: 3344
# Features extracted: 3345
# Features extracted: 3346
# Features extracted: 3347
# Features extracted: 3348
# Features extracted: 3349
# Features extracted: 3350
# Features extracted: 3351
# Features extracted: 3352
# Features extracted: 3353
# Features extracted: 3354
# Features extracted: 3355
# Features extracted: 3356
# Features extracted: 3357
# Features extracted: 3358
# Features extracted: 3359
# Features extracted: 3360
# Features extracted: 3361
# Features extracted: 3362
# Features extracted: 3363
# Features extracted: 3364
# Features extracted: 3365
# Features extracted: 3366
# Features extracted: 3367
# Features extracted: 3368
# Features extracted: 3369
# Features extracted: 3370
# Features extracted: 3371
# Features extracted: 3372
# Features extracted: 3373
# Features extracted: 3374
# Features extracted: 3375
# Features extracted: 3376
# Features extracted: 3377
# Features extracted: 3378
# Features extracted: 3379
# Features extracted: 3380
# Features extracted: 3381
# Features extracted: 3382
# Features extracted: 3383
# Features extracted: 3384
# Features extracted: 3385
# Features extracted: 3386
# Features extracted: 3387
# Features extracted: 3388
# Features extracted: 3389
# Features extracted: 3390
# Features extracted: 3391
# Features extracted: 3392
# Features extracted: 3393
# Features extracted: 3394
# Features extracted: 3395
# Features extracted: 3396
# Features extracted: 3397
# Features extracted: 3398
# Features extracted: 3399
# Features extracted: 3400
# Features extracted: 3401
# Features extracted: 3402
# Features extracted: 3403
# Features extracted: 3404
# Features extracted: 3405
# Features extracted: 3406
# Features extracted: 3407
# Features extracted: 3408
# Features extracted: 3409
# Features extracted: 3410
# Features extracted: 3411
# Features extracted: 3412
# Features extracted: 3413
# Features extracted: 3414
# Features extracted: 3415
# Features extracted: 3416
# Features extracted: 3417
# Features extracted: 3418
# Features extracted: 3419
# Features extracted: 3420
# Features extracted: 3421
# Features extracted: 3422
# Features extracted: 3423
# Features extracted: 3424
# Features extracted: 3425
# Features extracted: 3426
# Features extracted: 3427
# Features extracted: 3428
# Features extracted: 3429
# Features extracted: 3430
# Features extracted: 3431
# Features extracted: 3432
# Features extracted: 3433
# Features extracted: 3434
# Features extracted: 3435
# Features extracted: 3436
# Features extracted: 3437
# Features extracted: 3438
# Features extracted: 3439
# Features extracted: 3440
# Features extracted: 3441
# Features extracted: 3442
# Features extracted: 3443
# Features extracted: 3444
# Features extracted: 3445
# Features extracted: 3446
# Features extracted: 3447
# Features extracted: 3448
# Features extracted: 3449
# Features extracted: 3450
# Features extracted: 3451
# Features extracted: 3452
# Features extracted: 3453
# Features extracted: 3454
# Features extracted: 3455
# Features extracted: 3456
# Features extracted: 3457
# Features extracted: 3458
# Features extracted: 3459
# Features extracted: 3460
# Features extracted: 3461
# Features extracted: 3462
# Features extracted: 3463
# Features extracted: 3464
# Features extracted: 3465
# Features extracted: 3466
# Features extracted: 3467
# Features extracted: 3468
# Features extracted: 3469
# Features extracted: 3470
# Features extracted: 3471
# Features extracted: 3472
# Features extracted: 3473
# Features extracted: 3474
# Features extracted: 3475
# Features extracted: 3476
# Features extracted: 3477
# Features extracted: 3478
# Features extracted: 3479
# Features extracted: 3480
# Features extracted: 3481
# Features extracted: 3482
# Features extracted: 3483
# Features extracted: 3484
# Features extracted: 3485
# Features extracted: 3486
# Features extracted: 3487
# Features extracted: 3488
# Features extracted: 3489
# Features extracted: 3490
# Features extracted: 3491
# Features extracted: 3492
# Features extracted: 3493
# Features extracted: 3494
# Features extracted: 3495
# Features extracted: 3496
# Features extracted: 3497
# Features extracted: 3498
# Features extracted: 3499
# Features extracted: 3500
# Features extracted: 3501
# Features extracted: 3502
# Features extracted: 3503
# Features extracted: 3504
# Features extracted: 3505
# Features extracted: 3506
# Features extracted: 3507
# Features extracted: 3508
# Features extracted: 3509
# Features extracted: 3510
# Features extracted: 3511
# Features extracted: 3512
# Features extracted: 3513
# Features extracted: 3514
# Features extracted: 3515
# Features extracted: 3516
# Features extracted: 3517
# Features extracted: 3518
# Features extracted: 3519
# Features extracted: 3520
# Features extracted: 3521
# Features extracted: 3522
# Features extracted: 3523
# Features extracted: 3524
# Features extracted: 3525
# Features extracted: 3526
# Features extracted: 3527
# Features extracted: 3528
# Features extracted: 3529
# Features extracted: 3530
# Features extracted: 3531
# Features extracted: 3532
# Features extracted: 3533
# Features extracted: 3534
# Features extracted: 3535
# Features extracted: 3536
# Features extracted: 3537
# Features extracted: 3538
# Features extracted: 3539
# Features extracted: 3540
# Features extracted: 3541
# Features extracted: 3542
# Features extracted: 3543
# Features extracted: 3544
# Features extracted: 3545
# Features extracted: 3546
# Features extracted: 3547
# Features extracted: 3548
# Features extracted: 3549
# Features extracted: 3550
# Features extracted: 3551
# Features extracted: 3552
# Features extracted: 3553
# Features extracted: 3554
# Features extracted: 3555
# Features extracted: 3556
# Features extracted: 3557
# Features extracted: 3558
# Features extracted: 3559
# Features extracted: 3560
# Features extracted: 3561
# Features extracted: 3562
# Features extracted: 3563
# Features extracted: 3564
# Features extracted: 3565
# Features extracted: 3566
# Features extracted: 3567
# Features extracted: 3568
# Features extracted: 3569
# Features extracted: 3570
# Features extracted: 3571
# Features extracted: 3572
# Features extracted: 3573
# Features extracted: 3574
# Features extracted: 3575
# Features extracted: 3576
# Features extracted: 3577
# Features extracted: 3578
# Features extracted: 3579
# Features extracted: 3580
# Features extracted: 3581
# Features extracted: 3582
# Features extracted: 3583
# Features extracted: 3584
# Features extracted: 3585
# Features extracted: 3586
# Features extracted: 3587
# Features extracted: 3588
# Features extracted: 3589
# Features extracted: 3590
# Features extracted: 3591
# Features extracted: 3592
# Features extracted: 3593
# Features extracted: 3594
# Features extracted: 3595
# Features extracted: 3596
# Features extracted: 3597
# Features extracted: 3598
# Features extracted: 3599
# Features extracted: 3600
# Features extracted: 3601
# Features extracted: 3602
# Features extracted: 3603
# Features extracted: 3604
# Features extracted: 3605
# Features extracted: 3606
# Features extracted: 3607
# Features extracted: 3608
# Features extracted: 3609
# Features extracted: 3610
# Features extracted: 3611
# Features extracted: 3612
# Features extracted: 3613
# Features extracted: 3614
# Features extracted: 3615
# Features extracted: 3616
# Features extracted: 3617
# Features extracted: 3618
# Features extracted: 3619
# Features extracted: 3620
# Features extracted: 3621
# Features extracted: 3622
# Features extracted: 3623
# Features extracted: 3624
# Features extracted: 3625
# Features extracted: 3626
# Features extracted: 3627
# Features extracted: 3628
# Features extracted: 3629
# Features extracted: 3630
# Features extracted: 3631
# Features extracted: 3632
# Features extracted: 3633
# Features extracted: 3634
# Features extracted: 3635
# Features extracted: 3636
# Features extracted: 3637
# Features extracted: 3638
# Features extracted: 3639
# Features extracted: 3640
# Features extracted: 3641
# Features extracted: 3642
# Features extracted: 3643
# Features extracted: 3644
# Features extracted: 3645
# Features extracted: 3646
# Features extracted: 3647
# Features extracted: 3648
# Features extracted: 3649
# Features extracted: 3650
# Features extracted: 3651
# Features extracted: 3652
# Features extracted: 3653
# Features extracted: 3654
# Features extracted: 3655
# Features extracted: 3656
# Features extracted: 3657
# Features extracted: 3658
# Features extracted: 3659
# Features extracted: 3660
# Features extracted: 3661
# Features extracted: 3662
# Features extracted: 3663
# Features extracted: 3664
# Features extracted: 3665
# Features extracted: 3666
# Features extracted: 3667
# Features extracted: 3668
# Features extracted: 3669
# Features extracted: 3670
# Features extracted: 3671
# Features extracted: 3672
# Features extracted: 3673
# Features extracted: 3674
# Features extracted: 3675
# Features extracted: 3676
# Features extracted: 3677
# Features extracted: 3678
# Features extracted: 3679
# Features extracted: 3680
# Features extracted: 3681
# Features extracted: 3682
# Features extracted: 3683
# Features extracted: 3684
# Features extracted: 3685
# Features extracted: 3686
# Features extracted: 3687
# Features extracted: 3688
# Features extracted: 3689
# Features extracted: 3690
# Features extracted: 3691
# Features extracted: 3692
# Features extracted: 3693
# Features extracted: 3694
# Features extracted: 3695
# Features extracted: 3696
# Features extracted: 3697
# Features extracted: 3698
# Features extracted: 3699
# Features extracted: 3700
# Features extracted: 3701
# Features extracted: 3702
# Features extracted: 3703
# Features extracted: 3704
# Features extracted: 3705
# Features extracted: 3706
# Features extracted: 3707
# Features extracted: 3708
# Features extracted: 3709
# Features extracted: 3710
# Features extracted: 3711
# Features extracted: 3712
# Features extracted: 3713
# Features extracted: 3714
# Features extracted: 3715
# Features extracted: 3716
# Features extracted: 3717
# Features extracted: 3718
# Features extracted: 3719
# Features extracted: 3720
# Features extracted: 3721
# Features extracted: 3722
# Features extracted: 3723
# Features extracted: 3724
# Features extracted: 3725
# Features extracted: 3726
# Features extracted: 3727
# Features extracted: 3728
# Features extracted: 3729
# Features extracted: 3730
# Features extracted: 3731
# Features extracted: 3732
# Features extracted: 3733
# Features extracted: 3734
# Features extracted: 3735
# Features extracted: 3736
# Features extracted: 3737
# Features extracted: 3738
# Features extracted: 3739
# Features extracted: 3740
# Features extracted: 3741
# Features extracted: 3742
# Features extracted: 3743
# Features extracted: 3744
# Features extracted: 3745
# Features extracted: 3746
# Features extracted: 3747
# Features extracted: 3748
# Features extracted: 3749
# Features extracted: 3750
# Features extracted: 3751
# Features extracted: 3752
# Features extracted: 3753
# Features extracted: 3754
# Features extracted: 3755
# Features extracted: 3756
# Features extracted: 3757
# Features extracted: 3758
# Features extracted: 3759
# Features extracted: 3760
# Features extracted: 3761
# Features extracted: 3762
# Features extracted: 3763
# Features extracted: 3764
# Features extracted: 3765
# Features extracted: 3766
# Features extracted: 3767
# Features extracted: 3768
# Features extracted: 3769
# Features extracted: 3770
# Features extracted: 3771
# Features extracted: 3772
# Features extracted: 3773
# Features extracted: 3774
# Features extracted: 3775
# Features extracted: 3776
# Features extracted: 3777
# Features extracted: 3778
# Features extracted: 3779
# Features extracted: 3780
# Features extracted: 3781
# Features extracted: 3782
# Features extracted: 3783
# Features extracted: 3784
# Features extracted: 3785
# Features extracted: 3786
# Features extracted: 3787
# Features extracted: 3788
# Features extracted: 3789
# Features extracted: 3790
# Features extracted: 3791
# Features extracted: 3792
# Features extracted: 3793
# Features extracted: 3794
# Features extracted: 3795
# Features extracted: 3796
# Features extracted: 3797
# Features extracted: 3798
# Features extracted: 3799
# Features extracted: 3800
# Features extracted: 3801
# Features extracted: 3802
# Features extracted: 3803
# Features extracted: 3804
# Features extracted: 3805
# Features extracted: 3806
# Features extracted: 3807
# Features extracted: 3808
# Features extracted: 3809
# Features extracted: 3810
# Features extracted: 3811
# Features extracted: 3812
# Features extracted: 3813
# Features extracted: 3814
# Features extracted: 3815
# Features extracted: 3816
# Features extracted: 3817
# Features extracted: 3818
# Features extracted: 3819
# Features extracted: 3820
# Features extracted: 3821
# Features extracted: 3822
# Features extracted: 3823
# Features extracted: 3824
# Features extracted: 3825
# Features extracted: 3826
# Features extracted: 3827
# Features extracted: 3828
# Features extracted: 3829
# Features extracted: 3830
# Features extracted: 3831
# Features extracted: 3832
# Features extracted: 3833
# Features extracted: 3834
# Features extracted: 3835
# Features extracted: 3836
# Features extracted: 3837
# Features extracted: 3838
# Features extracted: 3839
# Features extracted: 3840
# Features extracted: 3841
# Features extracted: 3842
# Features extracted: 3843
# Features extracted: 3844
# Features extracted: 3845
# Features extracted: 3846
# Features extracted: 3847
# Features extracted: 3848
# Features extracted: 3849
# Features extracted: 3850
# Features extracted: 3851
# Features extracted: 3852
# Features extracted: 3853
# Features extracted: 3854
# Features extracted: 3855
# Features extracted: 3856
# Features extracted: 3857
# Features extracted: 3858
# Features extracted: 3859
# Features extracted: 3860
# Features extracted: 3861
# Features extracted: 3862
# Features extracted: 3863
# Features extracted: 3864
# Features extracted: 3865
# Features extracted: 3866
# Features extracted: 3867
# Features extracted: 3868
# Features extracted: 3869
# Features extracted: 3870
# Features extracted: 3871
# Features extracted: 3872
# Features extracted: 3873
# Features extracted: 3874
# Features extracted: 3875
# Features extracted: 3876
# Features extracted: 3877
# Features extracted: 3878
# Features extracted: 3879
# Features extracted: 3880
# Features extracted: 3881
# Features extracted: 3882
# Features extracted: 3883
# Features extracted: 3884
# Features extracted: 3885
# Features extracted: 3886
# Features extracted: 3887
# Features extracted: 3888
# Features extracted: 3889
# Features extracted: 3890
# Features extracted: 3891
# Features extracted: 3892
# Features extracted: 3893
# Features extracted: 3894
# Features extracted: 3895
# Features extracted: 3896
# Features extracted: 3897
# Features extracted: 3898
# Features extracted: 3899
# Features extracted: 3900
# Features extracted: 3901
# Features extracted: 3902
# Features extracted: 3903
# Features extracted: 3904
# Features extracted: 3905
# Features extracted: 3906
# Features extracted: 3907
# Features extracted: 3908
# Features extracted: 3909
# Features extracted: 3910
# Features extracted: 3911
# Features extracted: 3912
# Features extracted: 3913
# Features extracted: 3914
# Features extracted: 3915
# Features extracted: 3916
# Features extracted: 3917
# Features extracted: 3918
# Features extracted: 3919
# Features extracted: 3920
# Features extracted: 3921
# Features extracted: 3922
# Features extracted: 3923
# Features extracted: 3924
# Features extracted: 3925
# Features extracted: 3926
# Features extracted: 3927
# Features extracted: 3928
# Features extracted: 3929
# Features extracted: 3930
# Features extracted: 3931
# Features extracted: 3932
# Features extracted: 3933
# Features extracted: 3934
# Features extracted: 3935
# Features extracted: 3936
# Features extracted: 3937
# Features extracted: 3938
# Features extracted: 3939
# Features extracted: 3940
# Features extracted: 3941
# Features extracted: 3942
# Features extracted: 3943
# Features extracted: 3944
# Features extracted: 3945
# Features extracted: 3946
# Features extracted: 3947
# Features extracted: 3948
# Features extracted: 3949
# Features extracted: 3950
# Features extracted: 3951
# Features extracted: 3952
# Features extracted: 3953
# Features extracted: 3954
# Features extracted: 3955
# Features extracted: 3956
# Features extracted: 3957
# Features extracted: 3958
# Features extracted: 3959
# Features extracted: 3960
# Features extracted: 3961
# Features extracted: 3962
# Features extracted: 3963
# Features extracted: 3964
# Features extracted: 3965
# Features extracted: 3966
# Features extracted: 3967
# Features extracted: 3968
# Features extracted: 3969
# Features extracted: 3970
# Features extracted: 3971
# Features extracted: 3972
# Features extracted: 3973
# Features extracted: 3974
# Features extracted: 3975
# Features extracted: 3976
# Features extracted: 3977
# Features extracted: 3978
# Features extracted: 3979
# Features extracted: 3980
# Features extracted: 3981
# Features extracted: 3982
# Features extracted: 3983
# Features extracted: 3984
# Features extracted: 3985
# Features extracted: 3986
# Features extracted: 3987
# Features extracted: 3988
# Features extracted: 3989
# Features extracted: 3990
# Features extracted: 3991
# Features extracted: 3992
# Features extracted: 3993
# Features extracted: 3994
# Features extracted: 3995
# Features extracted: 3996
# Features extracted: 3997
# Features extracted: 3998
# Features extracted: 3999
# Features extracted: 4000
# Features extracted: 4001
# Features extracted: 4002
# Features extracted: 4003
# Features extracted: 4004
# Features extracted: 4005
# Features extracted: 4006
# Features extracted: 4007
# Features extracted: 4008
# Features extracted: 4009
# Features extracted: 4010
# Features extracted: 4011
# Features extracted: 4012
# Features extracted: 4013
# Features extracted: 4014
# Features extracted: 4015
# Features extracted: 4016
# Features extracted: 4017
# Features extracted: 4018
# Features extracted: 4019
# Features extracted: 4020
# Features extracted: 4021
# Features extracted: 4022
# Features extracted: 4023
# Features extracted: 4024
# Features extracted: 4025
# Features extracted: 4026
# Features extracted: 4027
# Features extracted: 4028
# Features extracted: 4029
# Features extracted: 4030
# Features extracted: 4031
# Features extracted: 4032
# Features extracted: 4033
# Features extracted: 4034
# Features extracted: 4035
# Features extracted: 4036
# Features extracted: 4037
# Features extracted: 4038
# Features extracted: 4039
# Features extracted: 4040
# Features extracted: 4041
# Features extracted: 4042
# Features extracted: 4043
# Features extracted: 4044
# Features extracted: 4045
# Features extracted: 4046
# Features extracted: 4047
# Features extracted: 4048
# Features extracted: 4049
# Features extracted: 4050
# Features extracted: 4051
# Features extracted: 4052
# Features extracted: 4053
# Features extracted: 4054
# Features extracted: 4055
# Features extracted: 4056
# Features extracted: 4057
# Features extracted: 4058
# Features extracted: 4059
# Features extracted: 4060
# Features extracted: 4061
# Features extracted: 4062
# Features extracted: 4063
# Features extracted: 4064
# Features extracted: 4065
# Features extracted: 4066
# Features extracted: 4067
# Features extracted: 4068
# Features extracted: 4069
# Features extracted: 4070
# Features extracted: 4071
# Features extracted: 4072
# Features extracted: 4073
# Features extracted: 4074
# Features extracted: 4075
# Features extracted: 4076
# Features extracted: 4077
# Features extracted: 4078
# Features extracted: 4079
# Features extracted: 4080
# Features extracted: 4081
# Features extracted: 4082
# Features extracted: 4083
# Features extracted: 4084
# Features extracted: 4085
# Features extracted: 4086
# Features extracted: 4087
# Features extracted: 4088
# Features extracted: 4089
# Features extracted: 4090
# Features extracted: 4091
# Features extracted: 4092
# Features extracted: 4093
# Features extracted: 4094
# Features extracted: 4095
# Features extracted: 4096
# Features extracted: 4097
# Features extracted: 4098
# Features extracted: 4099
# Features extracted: 4100
# Features extracted: 4101
# Features extracted: 4102
# Features extracted: 4103
# Features extracted: 4104
# Features extracted: 4105
# Features extracted: 4106
# Features extracted: 4107
# Features extracted: 4108
# Features extracted: 4109
# Features extracted: 4110
# Features extracted: 4111
# Features extracted: 4112
# Features extracted: 4113
# Features extracted: 4114
# Features extracted: 4115
# Features extracted: 4116
# Features extracted: 4117
# Features extracted: 4118
# Features extracted: 4119
# Features extracted: 4120
# Features extracted: 4121
# Features extracted: 4122
# Features extracted: 4123
# Features extracted: 4124
# Features extracted: 4125
# Features extracted: 4126
# Features extracted: 4127
# Features extracted: 4128
# Features extracted: 4129
# Features extracted: 4130
# Features extracted: 4131
# Features extracted: 4132
# Features extracted: 4133
# Features extracted: 4134
# Features extracted: 4135
# Features extracted: 4136
# Features extracted: 4137
# Features extracted: 4138
# Features extracted: 4139
# Features extracted: 4140
# Features extracted: 4141
# Features extracted: 4142
# Features extracted: 4143
# Features extracted: 4144
# Features extracted: 4145
# Features extracted: 4146
# Features extracted: 4147
# Features extracted: 4148
# Features extracted: 4149
# Features extracted: 4150
# Features extracted: 4151
# Features extracted: 4152
# Features extracted: 4153
# Features extracted: 4154
# Features extracted: 4155
# Features extracted: 4156
# Features extracted: 4157
# Features extracted: 4158
# Features extracted: 4159
# Features extracted: 4160
# Features extracted: 4161
# Features extracted: 4162
# Features extracted: 4163
# Features extracted: 4164
# Features extracted: 4165
# Features extracted: 4166
# Features extracted: 4167
# Features extracted: 4168
# Features extracted: 4169
# Features extracted: 4170
# Features extracted: 4171
# Features extracted: 4172
# Features extracted: 4173
# Features extracted: 4174
# Features extracted: 4175
# Features extracted: 4176
# Features extracted: 4177
# Features extracted: 4178
# Features extracted: 4179
# Features extracted: 4180
# Features extracted: 4181
# Features extracted: 4182
# Features extracted: 4183
# Features extracted: 4184
# Features extracted: 4185
# Features extracted: 4186
# Features extracted: 4187
# Features extracted: 4188
# Features extracted: 4189
# Features extracted: 4190
# Features extracted: 4191
# Features extracted: 4192
# Features extracted: 4193
# Features extracted: 4194
# Features extracted: 4195
# Features extracted: 4196
# Features extracted: 4197
# Features extracted: 4198
# Features extracted: 4199
# Features extracted: 4200
# Features extracted: 4201
# Features extracted: 4202
# Features extracted: 4203
# Features extracted: 4204
# Features extracted: 4205
# Features extracted: 4206
# Features extracted: 4207
# Features extracted: 4208
# Features extracted: 4209
# Features extracted: 4210
# Features extracted: 4211
# Features extracted: 4212
# Features extracted: 4213
# Features extracted: 4214
# Features extracted: 4215
# Features extracted: 4216
# Features extracted: 4217
# Features extracted: 4218
# Features extracted: 4219
# Features extracted: 4220
# Features extracted: 4221
# Features extracted: 4222
# Features extracted: 4223
# Features extracted: 4224
# Features extracted: 4225
# Features extracted: 4226
# Features extracted: 4227
# Features extracted: 4228
# Features extracted: 4229
# Features extracted: 4230
# Features extracted: 4231
# Features extracted: 4232
# Features extracted: 4233
# Features extracted: 4234
# Features extracted: 4235
# Features extracted: 4236
# Features extracted: 4237
# Features extracted: 4238
# Features extracted: 4239
# Features extracted: 4240
# Features extracted: 4241
# Features extracted: 4242
# Features extracted: 4243
# Features extracted: 4244
# Features extracted: 4245
# Features extracted: 4246
# Features extracted: 4247
# Features extracted: 4248
# Features extracted: 4249
# Features extracted: 4250
# Features extracted: 4251
# Features extracted: 4252
# Features extracted: 4253
# Features extracted: 4254
# Features extracted: 4255
# Features extracted: 4256
# Features extracted: 4257
# Features extracted: 4258
# Features extracted: 4259
# Features extracted: 4260
# Features extracted: 4261
# Features extracted: 4262
# Features extracted: 4263
# Features extracted: 4264
# Features extracted: 4265
# Features extracted: 4266
# Features extracted: 4267
# Features extracted: 4268
# Features extracted: 4269
# Features extracted: 4270
# Features extracted: 4271
# Features extracted: 4272
# Features extracted: 4273
# Features extracted: 4274
# Features extracted: 4275
# Features extracted: 4276
# Features extracted: 4277
# Features extracted: 4278
# Features extracted: 4279
# Features extracted: 4280
# Features extracted: 4281
# Features extracted: 4282
# Features extracted: 4283
# Features extracted: 4284
# Features extracted: 4285
# Features extracted: 4286
# Features extracted: 4287
# Features extracted: 4288
# Features extracted: 4289
# Features extracted: 4290
# Features extracted: 4291
# Features extracted: 4292
# Features extracted: 4293
# Features extracted: 4294
# Features extracted: 4295
# Features extracted: 4296
# Features extracted: 4297
# Features extracted: 4298
# Features extracted: 4299
# Features extracted: 4300
# Features extracted: 4301
# Features extracted: 4302
# Features extracted: 4303
# Features extracted: 4304
# Features extracted: 4305
# Features extracted: 4306
# Features extracted: 4307
# Features extracted: 4308
# Features extracted: 4309
# Features extracted: 4310
# Features extracted: 4311
# Features extracted: 4312
# Features extracted: 4313
# Features extracted: 4314
# Features extracted: 4315
# Features extracted: 4316
# Features extracted: 4317
# Features extracted: 4318
# Features extracted: 4319
# Features extracted: 4320
# Features extracted: 4321
# Features extracted: 4322
# Features extracted: 4323
# Features extracted: 4324
# Features extracted: 4325
# Features extracted: 4326
# Features extracted: 4327
# Features extracted: 4328
# Features extracted: 4329
# Features extracted: 4330
# Features extracted: 4331
# Features extracted: 4332
# Features extracted: 4333
# Features extracted: 4334
# Features extracted: 4335
# Features extracted: 4336
# Features extracted: 4337
# Features extracted: 4338
# Features extracted: 4339
# Features extracted: 4340
# Features extracted: 4341
# Features extracted: 4342
# Features extracted: 4343
# Features extracted: 4344
# Features extracted: 4345
# Features extracted: 4346
# Features extracted: 4347
# Features extracted: 4348
# Features extracted: 4349
# Features extracted: 4350
# Features extracted: 4351
# Features extracted: 4352
# Features extracted: 4353
# Features extracted: 4354
# Features extracted: 4355
# Features extracted: 4356
# Features extracted: 4357
# Features extracted: 4358
# Features extracted: 4359
# Features extracted: 4360
# Features extracted: 4361
# Features extracted: 4362
# Features extracted: 4363
# Features extracted: 4364
# Features extracted: 4365
# Features extracted: 4366
# Features extracted: 4367
# Features extracted: 4368
# Features extracted: 4369
# Features extracted: 4370
# Features extracted: 4371
# Features extracted: 4372
# Features extracted: 4373
# Features extracted: 4374
# Features extracted: 4375
# Features extracted: 4376
# Features extracted: 4377
# Features extracted: 4378
# Features extracted: 4379
# Features extracted: 4380
# Features extracted: 4381
# Features extracted: 4382
# Features extracted: 4383
# Features extracted: 4384
# Features extracted: 4385
# Features extracted: 4386
# Features extracted: 4387
# Features extracted: 4388
# Features extracted: 4389
# Features extracted: 4390
# Features extracted: 4391
# Features extracted: 4392
# Features extracted: 4393
# Features extracted: 4394
# Features extracted: 4395
# Features extracted: 4396
# Features extracted: 4397
# Features extracted: 4398
# Features extracted: 4399
# Features extracted: 4400
# Features extracted: 4401
# Features extracted: 4402
# Features extracted: 4403
# Features extracted: 4404
# Features extracted: 4405
# Features extracted: 4406
# Features extracted: 4407
# Features extracted: 4408
# Features extracted: 4409
# Features extracted: 4410
# Features extracted: 4411
# Features extracted: 4412
# Features extracted: 4413
# Features extracted: 4414
# Features extracted: 4415
# Features extracted: 4416
# Features extracted: 4417
# Features extracted: 4418
# Features extracted: 4419
# Features extracted: 4420
# Features extracted: 4421
# Features extracted: 4422
# Features extracted: 4423
# Features extracted: 4424
# Features extracted: 4425
# Features extracted: 4426
# Features extracted: 4427
# Features extracted: 4428
# Features extracted: 4429
# Features extracted: 4430
# Features extracted: 4431
# Features extracted: 4432
# Features extracted: 4433
# Features extracted: 4434
# Features extracted: 4435
# Features extracted: 4436
# Features extracted: 4437
# Features extracted: 4438
# Features extracted: 4439
# Features extracted: 4440
# Features extracted: 4441
# Features extracted: 4442
# Features extracted: 4443
# Features extracted: 4444
# Features extracted: 4445
# Features extracted: 4446
# Features extracted: 4447
# Features extracted: 4448
# Features extracted: 4449
# Features extracted: 4450
# Features extracted: 4451
# Features extracted: 4452
# Features extracted: 4453
# Features extracted: 4454
# Features extracted: 4455
# Features extracted: 4456
# Features extracted: 4457
# Features extracted: 4458
# Features extracted: 4459
# Features extracted: 4460
# Features extracted: 4461
# Features extracted: 4462
# Features extracted: 4463
# Features extracted: 4464
# Features extracted: 4465
# Features extracted: 4466
# Features extracted: 4467
# Features extracted: 4468
# Features extracted: 4469
# Features extracted: 4470
# Features extracted: 4471
# Features extracted: 4472
# Features extracted: 4473
# Features extracted: 4474
# Features extracted: 4475
# Features extracted: 4476
# Features extracted: 4477
# Features extracted: 4478
# Features extracted: 4479
# Features extracted: 4480
# Features extracted: 4481
# Features extracted: 4482
# Features extracted: 4483
# Features extracted: 4484
# Features extracted: 4485
# Features extracted: 4486
# Features extracted: 4487
# Features extracted: 4488
# Features extracted: 4489
# Features extracted: 4490
# Features extracted: 4491
# Features extracted: 4492
# Features extracted: 4493
# Features extracted: 4494
# Features extracted: 4495
# Features extracted: 4496
# Features extracted: 4497
# Features extracted: 4498
# Features extracted: 4499
# Features extracted: 4500
# Features extracted: 4501
# Features extracted: 4502
# Features extracted: 4503
# Features extracted: 4504
# Features extracted: 4505
# Features extracted: 4506
# Features extracted: 4507
# Features extracted: 4508
# Features extracted: 4509
# Features extracted: 4510
# Features extracted: 4511
# Features extracted: 4512
# Features extracted: 4513
# Features extracted: 4514
# Features extracted: 4515
# Features extracted: 4516
# Features extracted: 4517
# Features extracted: 4518
# Features extracted: 4519
# Features extracted: 4520
# Features extracted: 4521
# Features extracted: 4522
# Features extracted: 4523
# Features extracted: 4524
# Features extracted: 4525
# Features extracted: 4526
# Features extracted: 4527
# Features extracted: 4528
# Features extracted: 4529
# Features extracted: 4530
# Features extracted: 4531
# Features extracted: 4532
# Features extracted: 4533
# Features extracted: 4534
# Features extracted: 4535
# Features extracted: 4536
# Features extracted: 4537
# Features extracted: 4538
# Features extracted: 4539
# Features extracted: 4540
# Features extracted: 4541
# Features extracted: 4542
# Features extracted: 4543
# Features extracted: 4544
# Features extracted: 4545
# Features extracted: 4546
# Features extracted: 4547
# Features extracted: 4548
# Features extracted: 4549
# Features extracted: 4550
# Features extracted: 4551
# Features extracted: 4552
# Features extracted: 4553
# Features extracted: 4554
# Features extracted: 4555
# Features extracted: 4556
# Features extracted: 4557
# Features extracted: 4558
# Features extracted: 4559
# Features extracted: 4560
# Features extracted: 4561
# Features extracted: 4562
# Features extracted: 4563
# Features extracted: 4564
# Features extracted: 4565
# Features extracted: 4566
# Features extracted: 4567
# Features extracted: 4568
# Features extracted: 4569
# Features extracted: 4570
# Features extracted: 4571
# Features extracted: 4572
# Features extracted: 4573
# Features extracted: 4574
# Features extracted: 4575
# Features extracted: 4576
# Features extracted: 4577
# Features extracted: 4578
# Features extracted: 4579
# Features extracted: 4580
# Features extracted: 4581
# Features extracted: 4582
# Features extracted: 4583
# Features extracted: 4584
# Features extracted: 4585
# Features extracted: 4586
# Features extracted: 4587
# Features extracted: 4588
# Features extracted: 4589
# Features extracted: 4590
# Features extracted: 4591
# Features extracted: 4592
# Features extracted: 4593
# Features extracted: 4594
# Features extracted: 4595
# Features extracted: 4596
# Features extracted: 4597
# Features extracted: 4598
# Features extracted: 4599
# Features extracted: 4600
# Features extracted: 4601
# Features extracted: 4602
# Features extracted: 4603
# Features extracted: 4604
# Features extracted: 4605
# Features extracted: 4606
# Features extracted: 4607
# Features extracted: 4608
# Features extracted: 4609
# Features extracted: 4610
# Features extracted: 4611
# Features extracted: 4612
# Features extracted: 4613
# Features extracted: 4614
# Features extracted: 4615
# Features extracted: 4616
# Features extracted: 4617
# Features extracted: 4618
# Features extracted: 4619
# Features extracted: 4620
# Features extracted: 4621
# Features extracted: 4622
# Features extracted: 4623
# Features extracted: 4624
# Features extracted: 4625
# Features extracted: 4626
# Features extracted: 4627
# Features extracted: 4628
# Features extracted: 4629
# Features extracted: 4630
# Features extracted: 4631
# Features extracted: 4632
# Features extracted: 4633
# Features extracted: 4634
# Features extracted: 4635
# Features extracted: 4636
# Features extracted: 4637
# Features extracted: 4638
# Features extracted: 4639
# Features extracted: 4640
# Features extracted: 4641
# Features extracted: 4642
# Features extracted: 4643
# Features extracted: 4644
# Features extracted: 4645
# Features extracted: 4646
# Features extracted: 4647
# Features extracted: 4648
# Features extracted: 4649
# Features extracted: 4650
# Features extracted: 4651
# Features extracted: 4652
# Features extracted: 4653
# Features extracted: 4654
# Features extracted: 4655
# Features extracted: 4656
# Features extracted: 4657
# Features extracted: 4658
# Features extracted: 4659
# Features extracted: 4660
# Features extracted: 4661
# Features extracted: 4662
# Features extracted: 4663
# Features extracted: 4664
# Features extracted: 4665
# Features extracted: 4666
# Features extracted: 4667
# Features extracted: 4668
# Features extracted: 4669
# Features extracted: 4670
# Features extracted: 4671
# Features extracted: 4672
# Features extracted: 4673
# Features extracted: 4674
# Features extracted: 4675
# Features extracted: 4676
# Features extracted: 4677
# Features extracted: 4678
# Features extracted: 4679
# Features extracted: 4680
# Features extracted: 4681
# Features extracted: 4682
# Features extracted: 4683
# Features extracted: 4684
# Features extracted: 4685
# Features extracted: 4686
# Features extracted: 4687
# Features extracted: 4688
# Features extracted: 4689
# Features extracted: 4690
# Features extracted: 4691
# Features extracted: 4692
# Features extracted: 4693
# Features extracted: 4694
# Features extracted: 4695
# Features extracted: 4696
# Features extracted: 4697
# Features extracted: 4698
# Features extracted: 4699
# Features extracted: 4700
# Features extracted: 4701
# Features extracted: 4702
# Features extracted: 4703
# Features extracted: 4704
# Features extracted: 4705
# Features extracted: 4706
# Features extracted: 4707
# Features extracted: 4708
# Features extracted: 4709
# Features extracted: 4710
# Features extracted: 4711
# Features extracted: 4712
# Features extracted: 4713
# Features extracted: 4714
# Features extracted: 4715
# Features extracted: 4716
# Features extracted: 4717
# Features extracted: 4718
# Features extracted: 4719
# Features extracted: 4720
# Features extracted: 4721
# Features extracted: 4722
# Features extracted: 4723
# Features extracted: 4724
# Features extracted: 4725
# Features extracted: 4726
# Features extracted: 4727
# Features extracted: 4728
# Features extracted: 4729
# Features extracted: 4730
# Features extracted: 4731
# Features extracted: 4732
# Features extracted: 4733
# Features extracted: 4734
# Features extracted: 4735
# Features extracted: 4736
# Features extracted: 4737
# Features extracted: 4738
# Features extracted: 4739
# Features extracted: 4740
# Features extracted: 4741
# Features extracted: 4742
# Features extracted: 4743
# Features extracted: 4744
# Features extracted: 4745
# Features extracted: 4746
# Features extracted: 4747
# Features extracted: 4748
# Features extracted: 4749
# Features extracted: 4750
# Features extracted: 4751
# Features extracted: 4752
# Features extracted: 4753
# Features extracted: 4754
# Features extracted: 4755
# Features extracted: 4756
# Features extracted: 4757
# Features extracted: 4758
# Features extracted: 4759
# Features extracted: 4760
# Features extracted: 4761
# Features extracted: 4762
# Features extracted: 4763
# Features extracted: 4764
# Features extracted: 4765
# Features extracted: 4766
# Features extracted: 4767
# Features extracted: 4768
# Features extracted: 4769
# Features extracted: 4770
# Features extracted: 4771
# Features extracted: 4772
# Features extracted: 4773
# Features extracted: 4774
# Features extracted: 4775
# Features extracted: 4776
# Features extracted: 4777
# Features extracted: 4778
# Features extracted: 4779
# Features extracted: 4780
# Features extracted: 4781
# Features extracted: 4782
# Features extracted: 4783
# Features extracted: 4784
# Features extracted: 4785
# Features extracted: 4786
# Features extracted: 4787
# Features extracted: 4788
# Features extracted: 4789
# Features extracted: 4790
# Features extracted: 4791
# Features extracted: 4792
# Features extracted: 4793
# Features extracted: 4794
# Features extracted: 4795
# Features extracted: 4796
# Features extracted: 4797
# Features extracted: 4798
# Features extracted: 4799
# Features extracted: 4800
# Features extracted: 4801
# Features extracted: 4802
# Features extracted: 4803
# Features extracted: 4804
# Features extracted: 4805
# Features extracted: 4806
# Features extracted: 4807
# Features extracted: 4808
# Features extracted: 4809
# Features extracted: 4810
# Features extracted: 4811
# Features extracted: 4812
# Features extracted: 4813
# Features extracted: 4814
# Features extracted: 4815
# Features extracted: 4816
# Features extracted: 4817
# Features extracted: 4818
# Features extracted: 4819
# Features extracted: 4820
# Features extracted: 4821
# Features extracted: 4822
# Features extracted: 4823
# Features extracted: 4824
# Features extracted: 4825
# Features extracted: 4826
# Features extracted: 4827
# Features extracted: 4828
# Features extracted: 4829
# Features extracted: 4830
# Features extracted: 4831
# Features extracted: 4832
# Features extracted: 4833
# Features extracted: 4834
# Features extracted: 4835
# Features extracted: 4836
# Features extracted: 4837
# Features extracted: 4838
# Features extracted: 4839
# Features extracted: 4840
# Features extracted: 4841
# Features extracted: 4842
# Features extracted: 4843
# Features extracted: 4844
# Features extracted: 4845
# Features extracted: 4846
# Features extracted: 4847
# Features extracted: 4848
# Features extracted: 4849
# Features extracted: 4850
# Features extracted: 4851
# Features extracted: 4852
# Features extracted: 4853
# Features extracted: 4854
# Features extracted: 4855
# Features extracted: 4856
# Features extracted: 4857
# Features extracted: 4858
# Features extracted: 4859
# Features extracted: 4860
# Features extracted: 4861
# Features extracted: 4862
# Features extracted: 4863
# Features extracted: 4864
# Features extracted: 4865
# Features extracted: 4866
# Features extracted: 4867
# Features extracted: 4868
# Features extracted: 4869
# Features extracted: 4870
# Features extracted: 4871
# Features extracted: 4872
# Features extracted: 4873
# Features extracted: 4874
# Features extracted: 4875
# Features extracted: 4876
# Features extracted: 4877
# Features extracted: 4878
# Features extracted: 4879
# Features extracted: 4880
# Features extracted: 4881
# Features extracted: 4882
# Features extracted: 4883
# Features extracted: 4884
# Features extracted: 4885
# Features extracted: 4886
# Features extracted: 4887
# Features extracted: 4888
# Features extracted: 4889
# Features extracted: 4890
# Features extracted: 4891
# Features extracted: 4892
# Features extracted: 4893
# Features extracted: 4894
# Features extracted: 4895
# Features extracted: 4896
# Features extracted: 4897
# Features extracted: 4898
# Features extracted: 4899
# Features extracted: 4900
# Features extracted: 4901
# Features extracted: 4902
# Features extracted: 4903
# Features extracted: 4904
# Features extracted: 4905
# Features extracted: 4906
# Features extracted: 4907
# Features extracted: 4908
# Features extracted: 4909
# Features extracted: 4910
# Features extracted: 4911
# Features extracted: 4912
# Features extracted: 4913
# Features extracted: 4914
# Features extracted: 4915
# Features extracted: 4916
# Features extracted: 4917
# Features extracted: 4918
# Features extracted: 4919
# Features extracted: 4920
# Features extracted: 4921
# Features extracted: 4922
# Features extracted: 4923
# Features extracted: 4924
# Features extracted: 4925
# Features extracted: 4926
# Features extracted: 4927
# Features extracted: 4928
# Features extracted: 4929
# Features extracted: 4930
# Features extracted: 4931
# Features extracted: 4932
# Features extracted: 4933
# Features extracted: 4934
# Features extracted: 4935
# Features extracted: 4936
# Features extracted: 4937
# Features extracted: 4938
# Features extracted: 4939
# Features extracted: 4940
# Features extracted: 4941
# Features extracted: 4942
# Features extracted: 4943
# Features extracted: 4944
# Features extracted: 4945
# Features extracted: 4946
# Features extracted: 4947
# Features extracted: 4948
# Features extracted: 4949
# Features extracted: 4950
# Features extracted: 4951
# Features extracted: 4952
# Features extracted: 4953
# Features extracted: 4954
# Features extracted: 4955
# Features extracted: 4956
# Features extracted: 4957
# Features extracted: 4958
# Features extracted: 4959
# Features extracted: 4960
# Features extracted: 4961
# Features extracted: 4962
# Features extracted: 4963
# Features extracted: 4964
# Features extracted: 4965
# Features extracted: 4966
# Features extracted: 4967
# Features extracted: 4968
# Features extracted: 4969
# Features extracted: 4970
# Features extracted: 4971
# Features extracted: 4972
# Features extracted: 4973
# Features extracted: 4974
# Features extracted: 4975
# Features extracted: 4976
# Features extracted: 4977
# Features extracted: 4978
# Features extracted: 4979
# Features extracted: 4980
# Features extracted: 4981
# Features extracted: 4982
# Features extracted: 4983
# Features extracted: 4984
# Features extracted: 4985
# Features extracted: 4986
# Features extracted: 4987
# Features extracted: 4988
# Features extracted: 4989
# Features extracted: 4990
# Features extracted: 4991
# Features extracted: 4992
# Features extracted: 4993
# Features extracted: 4994
# Features extracted: 4995
# Features extracted: 4996
# Features extracted: 4997
# Features extracted: 4998
# Features extracted: 4999
# Features extracted: 5000
# Features extracted: 5001
# Features extracted: 5002
# Features extracted: 5003
# Features extracted: 5004
# Features extracted: 5005
# Features extracted: 5006
# Features extracted: 5007
# Features extracted: 5008
# Features extracted: 5009
# Features extracted: 5010
# Features extracted: 5011
# Features extracted: 5012
# Features extracted: 5013
# Features extracted: 5014
# Features extracted: 5015
# ...
# Features extracted: 7458
# Features extracted: 7459
# Features extracted: 7460
# Features extracted: 7461
# Features extracted: 7462
# Features extracted: 7463
# Features extracted: 7464
# Features extracted: 7465
# Features extracted: 7466
# Features extracted: 7467
# Features extracted: 7468
# Features extracted: 7469
# Features extracted: 7470
# Features extracted: 7471
# Features extracted: 7472
# Features extracted: 7473
# Features extracted: 7474
# Features extracted: 7475
# Features extracted: 7476
# Features extracted: 7477
# Features extracted: 7478
# Features extracted: 7479
# Features extracted: 7480
# Features extracted: 7481
# Features extracted: 7482
# Features extracted: 7483
# Features extracted: 7484
# Features extracted: 7485
# Features extracted: 7486
# Features extracted: 7487
# Features extracted: 7488
# Features extracted: 7489
# Features extracted: 7490
# Features extracted: 7491
# Features extracted: 7492
# Features extracted: 7493
# Features extracted: 7494
# Features extracted: 7495
# Features extracted: 7496
# Features extracted: 7497
# Features extracted: 7498
# Features extracted: 7499
# Features extracted: 7500
# Features extracted: 7501
# Features extracted: 7502
# Features extracted: 7503
# Features extracted: 7504
# Features extracted: 7505
# Features extracted: 7506
# Features extracted: 7507
# Features extracted: 7508
# Features extracted: 7509
# Features extracted: 7510
# Features extracted: 7511
# Features extracted: 7512
# Features extracted: 7513
# Features extracted: 7514
# Features extracted: 7515
# Features extracted: 7516
# Features extracted: 7517
# Features extracted: 7518
# Features extracted: 7519
# Features extracted: 7520
# Features extracted: 7521
# Features extracted: 7522
# Features extracted: 7523
# Features extracted: 7524
# Features extracted: 7525
# Features extracted: 7526
# Features extracted: 7527
# Features extracted: 7528
# Features extracted: 7529
# Features extracted: 7530
# Features extracted: 7531
# Features extracted: 7532
# Features extracted: 7533
# Features extracted: 7534
# Features extracted: 7535
# Features extracted: 7536
# Features extracted: 7537
# Features extracted: 7538
# Features extracted: 7539
# Features extracted: 7540
# Features extracted: 7541
# Features extracted: 7542
# Features extracted: 7543
# Features extracted: 7544
# Features extracted: 7545
# Features extracted: 7546
# Features extracted: 7547
# Features extracted: 7548
# Features extracted: 7549
# Features extracted: 7550
# Features extracted: 7551
# Features extracted: 7552
# Features extracted: 7553
# Features extracted: 7554
# Features extracted: 7555
# Features extracted: 7556
# Features extracted: 7557
# Features extracted: 7558
# Features extracted: 7559
# Features extracted: 7560
# Features extracted: 7561
# Features extracted: 7562
# Features extracted: 7563
# Features extracted: 7564
# Features extracted: 7565
# Features extracted: 7566
# Features extracted: 7567
# Features extracted: 7568
# Features extracted: 7569
# Features extracted: 7570
# Features extracted: 7571
# Features extracted: 7572
# Features extracted: 7573
# Features extracted: 7574
# Features extracted: 7575
# Features extracted: 7576
# Features extracted: 7577
# Features extracted: 7578
# Features extracted: 7579
# Features extracted: 7580
# Features extracted: 7581
# Features extracted: 7582
# Features extracted: 7583
# Features extracted: 7584
# Features extracted: 7585
# Features extracted: 7586
# Features extracted: 7587
# Features extracted: 7588
# Features extracted: 7589
# Features extracted: 7590
# Features extracted: 7591
# Features extracted: 7592
# Features extracted: 7593
# Features extracted: 7594
# Features extracted: 7595
# Features extracted: 7596
# Features extracted: 7597
# Features extracted: 7598
# Features extracted: 7599
# Features extracted: 7600
# Features extracted: 7601
# Features extracted: 7602
# Features extracted: 7603
# Features extracted: 7604
# Features extracted: 7605
# Features extracted: 7606
# Features extracted: 7607
# Features extracted: 7608
# Features extracted: 7609
# Features extracted: 7610
# Features extracted: 7611
# Features extracted: 7612
# Features extracted: 7613
# Features extracted: 7614
# Features extracted: 7615
# Features extracted: 7616
# Features extracted: 7617
# Features extracted: 7618
# Features extracted: 7619
# Features extracted: 7620
# Features extracted: 7621
# Features extracted: 7622
# Features extracted: 7623
# Features extracted: 7624
# Features extracted: 7625
# Features extracted: 7626
# Features extracted: 7627
# Features extracted: 7628
# Features extracted: 7629
# Features extracted: 7630
# Features extracted: 7631
# Features extracted: 7632
# Features extracted: 7633
# Features extracted: 7634
# Features extracted: 7635
# Features extracted: 7636
# Features extracted: 7637
# Features extracted: 7638
# Features extracted: 7639
# Features extracted: 7640
# Features extracted: 7641
# Features extracted: 7642
# Features extracted: 7643
# Features extracted: 7644
# Features extracted: 7645
# Features extracted: 7646
# Features extracted: 7647
# Features extracted: 7648
# Features extracted: 7649
# Features extracted: 7650
# Features extracted: 7651
# Features extracted: 7652
# Features extracted: 7653
# Features extracted: 7654
# Features extracted: 7655
# Features extracted: 7656
# Features extracted: 7657
# Features extracted: 7658
# Features extracted: 7659
# Features extracted: 7660
# Features extracted: 7661
# Features extracted: 7662
# Features extracted: 7663
# Features extracted: 7664
# Features extracted: 7665
# Features extracted: 7666
# Features extracted: 7667
# Features extracted: 7668
# Features extracted: 7669
# Features extracted: 7670
# Features extracted: 7671
# Features extracted: 7672
# Features extracted: 7673
# Features extracted: 7674
# Features extracted: 7675
# Features extracted: 7676
# Features extracted: 7677
# Features extracted: 7678
# Features extracted: 7679
# Features extracted: 7680
# Features extracted: 7681
# Features extracted: 7682
# Features extracted: 7683
# Features extracted: 7684
# Features extracted: 7685
# Features extracted: 7686
# Features extracted: 7687
# Features extracted: 7688
# Features extracted: 7689
# Features extracted: 7690
# Features extracted: 7691
# Features extracted: 7692
# Features extracted: 7693
# Features extracted: 7694
# Features extracted: 7695
# Features extracted: 7696
# Features extracted: 7697
# Features extracted: 7698
# Features extracted: 7699
# Features extracted: 7700
# Features extracted: 7701
# Features extracted: 7702
# Features extracted: 7703
# Features extracted: 7704
# Features extracted: 7705
# Features extracted: 7706
# Features extracted: 7707
# Features extracted: 7708
# Features extracted: 7709
# Features extracted: 7710
# Features extracted: 7711
# Features extracted: 7712
# Features extracted: 7713
# Features extracted: 7714
# Features extracted: 7715
# Features extracted: 7716
# Features extracted: 7717
# Features extracted: 7718
# Features extracted: 7719
# Features extracted: 7720
# Features extracted: 7721
# Features extracted: 7722
# Features extracted: 7723
# Features extracted: 7724
# Features extracted: 7725
# Features extracted: 7726
# Features extracted: 7727
# Features extracted: 7728
# Features extracted: 7729
# Features extracted: 7730
# Features extracted: 7731
# Features extracted: 7732
# Features extracted: 7733
# Features extracted: 7734
# Features extracted: 7735
# Features extracted: 7736
# Features extracted: 7737
# Features extracted: 7738
# Features extracted: 7739
# Features extracted: 7740
# Features extracted: 7741
# Features extracted: 7742
# Features extracted: 7743
# Features extracted: 7744
# Features extracted: 7745
# Features extracted: 7746
# Features extracted: 7747
# Features extracted: 7748
# Features extracted: 7749
# Features extracted: 7750
# Features extracted: 7751
# Features extracted: 7752
# Features extracted: 7753
# Features extracted: 7754
# Features extracted: 7755
# Features extracted: 7756
# Features extracted: 7757
# Features extracted: 7758
# Features extracted: 7759
# Features extracted: 7760
# Features extracted: 7761
# Features extracted: 7762
# Features extracted: 7763
# Features extracted: 7764
# Features extracted: 7765
# Features extracted: 7766
# Features extracted: 7767
# Features extracted: 7768
# Features extracted: 7769
# Features extracted: 7770
# Features extracted: 7771
# Features extracted: 7772
# Features extracted: 7773
# Features extracted: 7774
# Features extracted: 7775
# Features extracted: 7776
# Features extracted: 7777
# Features extracted: 7778
# Features extracted: 7779
# Features extracted: 7780
# Features extracted: 7781
# Features extracted: 7782
# Features extracted: 7783
# Features extracted: 7784
# Features extracted: 7785
# Features extracted: 7786
# Features extracted: 7787
# Features extracted: 7788
# Features extracted: 7789
# Features extracted: 7790
# Features extracted: 7791
# Features extracted: 7792
# Features extracted: 7793
# Features extracted: 7794
# Features extracted: 7795
# Features extracted: 7796
# Features extracted: 7797
# Features extracted: 7798
# Features extracted: 7799
# Features extracted: 7800
# Features extracted: 7801
# Features extracted: 7802
# Features extracted: 7803
# Features extracted: 7804
# Features extracted: 7805
# Features extracted: 7806
# Features extracted: 7807
# Features extracted: 7808
# Features extracted: 7809
# Features extracted: 7810
# Features extracted: 7811
# Features extracted: 7812
# Features extracted: 7813
# Features extracted: 7814
# Features extracted: 7815
# Features extracted: 7816
# Features extracted: 7817
# Features extracted: 7818
# Features extracted: 7819
# Features extracted: 7820
# Features extracted: 7821
# Features extracted: 7822
# Features extracted: 7823
# Features extracted: 7824
# Features extracted: 7825
# Features extracted: 7826
# Features extracted: 7827
# Features extracted: 7828
# Features extracted: 7829
# Features extracted: 7830
# Features extracted: 7831
# Features extracted: 7832
# Features extracted: 7833
# Features extracted: 7834
# Features extracted: 7835
# Features extracted: 7836
# Features extracted: 7837
# Features extracted: 7838
# Features extracted: 7839
# Features extracted: 7840
# Features extracted: 7841
# Features extracted: 7842
# Features extracted: 7843
# Features extracted: 7844
# Features extracted: 7845
# Features extracted: 7846
# Features extracted: 7847
# Features extracted: 7848
# Features extracted: 7849
# Features extracted: 7850
# Features extracted: 7851
# Features extracted: 7852
# Features extracted: 7853
# Features extracted: 7854
# Features extracted: 7855
# Features extracted: 7856
# Features extracted: 7857
# Features extracted: 7858
# Features extracted: 7859
# Features extracted: 7860
# Features extracted: 7861
# Features extracted: 7862
# Features extracted: 7863
# Features extracted: 7864
# Features extracted: 7865
# Features extracted: 7866
# Features extracted: 7867
# Features extracted: 7868
# Features extracted: 7869
# Features extracted: 7870
# Features extracted: 7871
# Features extracted: 7872
# Features extracted: 7873
# Features extracted: 7874
# Features extracted: 7875
# Features extracted: 7876
# Features extracted: 7877
# Features extracted: 7878
# Features extracted: 7879
# Features extracted: 7880
# Features extracted: 7881
# Features extracted: 7882
# Features extracted: 7883
# Features extracted: 7884
# Features extracted: 7885
# Features extracted: 7886
# Features extracted: 7887
# Features extracted: 7888
# Features extracted: 7889
# Features extracted: 7890
# Features extracted: 7891
# Features extracted: 7892
# Features extracted: 7893
# Features extracted: 7894
# Features extracted: 7895
# Features extracted: 7896
# Features extracted: 7897
# Features extracted: 7898
# Features extracted: 7899
# Features extracted: 7900
# Features extracted: 7901
# Features extracted: 7902
# Features extracted: 7903
# Features extracted: 7904
# Features extracted: 7905
# Features extracted: 7906
# Features extracted: 7907
# Features extracted: 7908
# Features extracted: 7909
# Features extracted: 7910
# Features extracted: 7911
# Features extracted: 7912
# Features extracted: 7913
# Features extracted: 7914
# Features extracted: 7915
# Features extracted: 7916
# Features extracted: 7917
# Features extracted: 7918
# Features extracted: 7919
# Features extracted: 7920
# Features extracted: 7921
# Features extracted: 7922
# Features extracted: 7923
# Features extracted: 7924
# Features extracted: 7925
# Features extracted: 7926
# Features extracted: 7927
# Features extracted: 7928
# Features extracted: 7929
# Features extracted: 7930
# Features extracted: 7931
# Features extracted: 7932
# Features extracted: 7933
# Features extracted: 7934
# Features extracted: 7935
# Features extracted: 7936
# Features extracted: 7937
# Features extracted: 7938
# Features extracted: 7939
# Features extracted: 7940
# Features extracted: 7941
# Features extracted: 7942
# Features extracted: 7943
# Features extracted: 7944
# Features extracted: 7945
# Features extracted: 7946
# Features extracted: 7947
# Features extracted: 7948
# Features extracted: 7949
# Features extracted: 7950
# Features extracted: 7951
# Features extracted: 7952
# Features extracted: 7953
# Features extracted: 7954
# Features extracted: 7955
# Features extracted: 7956
# Features extracted: 7957
# Features extracted: 7958
# Features extracted: 7959
# Features extracted: 7960
# Features extracted: 7961
# Features extracted: 7962
# Features extracted: 7963
# Features extracted: 7964
# Features extracted: 7965
# Features extracted: 7966
# Features extracted: 7967
# Features extracted: 7968
# Features extracted: 7969
# Features extracted: 7970
# Features extracted: 7971
# Features extracted: 7972
# Features extracted: 7973
# Features extracted: 7974
# Features extracted: 7975
# Features extracted: 7976
# Features extracted: 7977
# Features extracted: 7978
# Features extracted: 7979
# Features extracted: 7980
# Features extracted: 7981
# Features extracted: 7982
# Features extracted: 7983
# Features extracted: 7984
# Features extracted: 7985
# Features extracted: 7986
# Features extracted: 7987
# Features extracted: 7988
# Features extracted: 7989
# Features extracted: 7990
# Features extracted: 7991
# Features extracted: 7992
# Features extracted: 7993
# Features extracted: 7994
# Features extracted: 7995
# Features extracted: 7996
# Features extracted: 7997
# Features extracted: 7998
# Features extracted: 7999
# Features extracted: 8000
# Features extracted: 8001
# Features extracted: 8002
# Features extracted: 8003
# Features extracted: 8004
# Features extracted: 8005
# Features extracted: 8006
# Features extracted: 8007
# Features extracted: 8008
# Features extracted: 8009
# Features extracted: 8010
# Features extracted: 8011
# Features extracted: 8012
# Features extracted: 8013
# Features extracted: 8014
# Features extracted: 8015
# Features extracted: 8016
# Features extracted: 8017
# Features extracted: 8018
# Features extracted: 8019
# Features extracted: 8020
# Features extracted: 8021
# Features extracted: 8022
# Features extracted: 8023
# Features extracted: 8024
# Features extracted: 8025
# Features extracted: 8026
# Features extracted: 8027
# Features extracted: 8028
# Features extracted: 8029
# Features extracted: 8030
# Features extracted: 8031
# Features extracted: 8032
# Features extracted: 8033
# Features extracted: 8034
# Features extracted: 8035
# Features extracted: 8036
# Features extracted: 8037
# Features extracted: 8038
# Features extracted: 8039
# Features extracted: 8040
# Features extracted: 8041
# Features extracted: 8042
# Features extracted: 8043
# Features extracted: 8044
# Features extracted: 8045
# Features extracted: 8046
# Features extracted: 8047
# Features extracted: 8048
# Features extracted: 8049
# Features extracted: 8050
# Features extracted: 8051
# Features extracted: 8052
# Features extracted: 8053
# Features extracted: 8054
# Features extracted: 8055
# Features extracted: 8056
# Features extracted: 8057
# Features extracted: 8058
# Features extracted: 8059
# Features extracted: 8060
# Features extracted: 8061
# Features extracted: 8062
# Features extracted: 8063
# Features extracted: 8064
# Features extracted: 8065
# Features extracted: 8066
# Features extracted: 8067
# Features extracted: 8068
# Features extracted: 8069
# Features extracted: 8070
# Features extracted: 8071
# Features extracted: 8072
# Features extracted: 8073
# Features extracted: 8074
# Features extracted: 8075
# Features extracted: 8076
# Features extracted: 8077
# Features extracted: 8078
# Features extracted: 8079
# Features extracted: 8080
# Features extracted: 8081
# Features extracted: 8082
# Features extracted: 8083
# Features extracted: 8084
# Features extracted: 8085
# Features extracted: 8086
# Features extracted: 8087
# Features extracted: 8088
# Features extracted: 8089
# Features extracted: 8090
# Features extracted: 8091
# Features extracted: 8092
# Features extracted: 8093
# Features extracted: 8094
# Features extracted: 8095
# Features extracted: 8096
# Extracted Features: 8096

# %%
# REFERENCE CODE
# You can reference this output to understand the feature dictionary variable

i = 0
for key, value in features.items():
  print("key: ", key, "value: ", value)
  i += 1
  if i==9:
    break

print(value.shape)
print(len(features))
# Out:
# key:  2474092890_6c0781a8ed value:  [[1.9167701  2.820439   0.72505444 ... 0.         4.095129   0.        ]]
# key:  3120189281_1938460e85 value:  [[0.7948173 0.        2.7716985 ... 0.        6.0868697 0.       ]]
# key:  3226796100_08c49cfa5c value:  [[0.         0.04009837 0.         ... 0.         3.2997937  1.5370014 ]]
# key:  2695962887_a1647c567b value:  [[0. 0. 0. ... 0. 0. 0.]]
# key:  3216901052_269ace7b3c value:  [[0.88462585 0.         0.79778147 ... 0.         0.3726354  2.7502291 ]]
# key:  3264937930_9623496b64 value:  [[0.        0.        2.5311522 ... 5.325687  0.        0.       ]]
# key:  3457210101_3533edebc8 value:  [[1.7561268 0.        0.        ... 0.        0.        3.171581 ]]
# key:  3241965735_8742782a70 value:  [[0.43854058 3.607577   1.507893   ... 0.         0.7172942  1.5967948 ]]
# key:  3215238223_29de2b35cb value:  [[0.        1.0109415 0.        ... 2.643682  0.        0.       ]]
# (1, 4096)
# 8096

# %% [markdown]
# # 3. Prepare Text Data [2 Marks]

# %%
import string

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# %%
# extract descriptions for images
def load_descriptions(doc):
	mapping = dict()
	# process lines
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		if len(line) < 2:
			continue
		# take the first token as the image id, the rest as the description
		image_id, image_desc =  tokens[0], tokens[1:]

		# remove filename from image id
		image_id = image_id.split('.')[0]

		# convert description tokens back to string
		image_desc = ' '.join(image_desc)
	
		# create the list if needed
		if image_id not in mapping:
			mapping[image_id] = list()
	 
		# store description
		mapping[image_id].append(image_desc)
	
	return mapping

# %%
# We will clean the text in the following ways in order to reduce the size of the vocabulary of words we will need to work with:

# 1. Convert all words to lowercase.
# 2. Remove all punctuation.
# 3. Remove all words that are one character or less in length (e.g. ‘a’).
# 4. Remove all words with numbers in them.

def clean_descriptions(descriptions):
	
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for key, desc_list in descriptions.items():
		for i in range(len(desc_list)):
			desc = desc_list[i]

			# tokenize desc using split 
			desc = desc.split()

			# convert all the words in desc to lower case
			desc = [word.lower() for word in desc]

			# remove punctuation from each token using translate function 
			# pass the "table" variable to this function
			desc = [w.translate(table) for w in desc]

			# remove hanging 's' and 'a'
			desc = [word for word in desc if len(word)>1]

			# remove tokens with numbers in them using isalpha
			desc = [word for word in desc if word.isalpha()]
			# store as string
			desc_list[i] =  ' '.join(desc)

# %%
# convert the loaded descriptions into a vocabulary of words
def to_vocabulary(descriptions):

	# build a list of all description strings
	all_desc = set()
	for key in descriptions.keys():
		[all_desc.update(d.split()) for d in descriptions[key]]
	return all_desc

# %%
# save descriptions to file, one per line
def save_descriptions(descriptions, filename):
	lines = list()
	for key, desc_list in descriptions.items():
		for desc in desc_list:
			lines.append(key + ' ' + desc)
	data = '\n'.join(lines)
	file = open(filename, 'w')
	file.write(data)
	file.close()

# %%
# Use the above functions in the code below-

filename = root+'Flickr8k_text/Flickr8k.token.txt'

# load descriptions (pass the filename)
doc = load_doc(filename)

# parse descriptions (pass doc)
descriptions = load_descriptions(doc)
print('Loaded: %d ' % len(descriptions))

# clean the descriptions
clean_descriptions(descriptions)

# summarize descriptions to a vocabulary of words
vocabulary = to_vocabulary(descriptions)
print('Vocabulary Size: %d' % len(vocabulary))

# save to file
save_descriptions(descriptions, 'descriptions.txt')

# You should get the following output for the above code
# Out:
# Loaded: 8092
# Vocabulary Size: 8763

# %% [markdown]
# # 4. Develop Deep Learning Model [4 Marks]

# %%
from numpy import array
from pickle import load

# You need to import the following functions from tensorflow.keras library
# Tokenizer, pad_sequences, to_categorical, plot_model, Model, Input, Dense, LSTM, Embedding, Dropout, add, ModelCheckpoint

#####
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import add
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
# load a pre-defined list of photo identifiers
def load_set(filename):
	# load document filename using the function defined earlier
	doc = load_doc(filename)
	dataset = list()
 
	# process doc line by line using split
	for line in doc.split('\n'):
		# skip empty lines
		if len(line) < 1:
			continue
		# get the image identifier
		identifier = line.split('.')[0]
		dataset.append(identifier)
	return set(dataset)

# load clean descriptions into memory
def load_clean_descriptions(filename, dataset):
	# load document filename using function defined earlier
	doc = load_doc(filename)
	descriptions = dict()
 
  # process doc line by line using split
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()

		# take the first token as the image id, the rest as the description
		image_id, image_desc = tokens[0], tokens[1:]
		
		# skip images not in the set
		if image_id in dataset:
			# create list
			if image_id not in descriptions:
				descriptions[image_id] = list()
			# wrap description in tokens
			desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
			# store
			descriptions[image_id].append(desc)
	return descriptions

# load photo features
def load_photo_features(filename, dataset):
	# load all features from filename
	all_features = load(open(filename, 'rb'))

	# filter features
	features = {k: all_features.get(k,"none") for k in dataset}
	return features

# covert a dictionary of clean descriptions to a list of descriptions
def to_lines(descriptions):
	all_desc = list()
	for key in descriptions.keys():
		[all_desc.append(d) for d in descriptions[key]]
	return all_desc

# fit a tokenizer given caption descriptions
def create_tokenizer(descriptions):
	# Convert the descriptions to lines
	lines = to_lines(descriptions)
  
	# Create a tokenizer object
	tokenizer = Tokenizer()

	# fit the tokenizer using fit_on_texts on lines
	#####
	tokenizer.fit_on_texts(lines)

	return tokenizer

# calculate the length of the description with the most words
def max_length(descriptions):
	# Convert descriptions to lines
	lines = to_lines(descriptions)
	return max(len(d.split()) for d in lines)

# %%
# REFERENCE CODE
# X1,		    X2 (text sequence), 				                 		y (word)
# photo	    startseq, 									                    little
# photo	    startseq, little,						                   	girl
# photo	    startseq, little, girl, 			              		running
# photo	    startseq, little, girl, running, 		          	in
# photo	    startseq, little, girl, running, in, 		        field
# photo	    startseq, little, girl, running, in, field,     endseq

# You need to create the sequences in abovee format for your data

# create sequences of images, input sequences and output words for an image
def create_sequences(tokenizer, max_length, desc_list, photo, vocab_size):
	# Define as empty lists
  X1, X2, y = list(), list(), list()

	# walk through each description for the image
  for desc in desc_list:
		# encode the sequence using texts_to_sequences (consider first element)
    seq = tokenizer.texts_to_sequences([desc])[0]

		# split one sequence into multiple X,y pairs
    for i in range(1, len(seq)):
			# split into input and output pair as shown in reference code
      in_seq, out_seq = seq[:i], seq[i]
			# pad input sequence to max_length(consider first element)
      in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
			# encode output sequence to one hot vectors with vocab size as num of classes (consider first element)
      out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
			# store
      X1.append(photo)
      X2.append(in_seq)
      y.append(out_seq)
  return array(X1), array(X2), array(y)

# %% [markdown]
# **You need to build a model with the following layers.
# We have explained the inputs and outputs in the comments in the following cells.**

# %%
from IPython.display import Image
Image('model.png')

# %%
# define the captioning model
def define_model(vocab_size, max_length):
  # feature extractor model
	# define an input of shape (4096,)
  inputs1 = Input(shape=(4096,))
	# Add a dropout layer of 0.5
  fe1 = Dropout(0.5)(inputs1)
	# Add a dense layer of 256 units with relu activation
  fe2 = Dense(256, activation='relu')(fe1)

	# sequence model
	# Define input of shape (max_length,)
  inputs2 = Input(shape=(max_length,))
	# Define an 256 dimension embedding layer with the vocab_size and parameter mark_zero=True
  se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
	# Add a dropout layer of 0.4
  se2 = Dropout(0.5)(se1)
	# Add an LSTM layer with 256 units
  se3 = LSTM(256)(se2)

	# decoder model
	# Add the outputs of feature extractor model and sequence model
  decoder1 = add([fe2, se3])
	# Feed it to a dense layer of 512 units with relu activation
  decoder2 = Dense(512, activation='relu')(decoder1)
	# Add a dense layer with no. of units=vocab_size, and softmax activation
  outputs = Dense(vocab_size, activation='softmax')(decoder2)

	# tie it together and create a model instance which takes input as [image, seq] and gives output as [word]  
  model = Model(inputs=[inputs1, inputs2], outputs=outputs)
  
	# compile model with categorical crossentropy loss and adam optimizer
  model.compile(loss='categorical_crossentropy', optimizer='adam')
	
	# summarize model
  model.summary()
  
	# check if this is same as image provided 
  plot_model(model, to_file='model.png', show_shapes=True)
  return model

# data generator, intended to be used in a call to model.fit()
def data_generator(descriptions, photos, tokenizer, max_length, vocab_size):
	# loop for ever over images
	while 1:
		for key, desc_list in descriptions.items():
			# retrieve the photo feature
			photo = photos[key][0]
			# create the sequences
			in_img, in_seq, out_word = create_sequences(tokenizer, max_length, desc_list, photo, vocab_size)
			yield [in_img, in_seq], out_word

# load training dataset (6K)
filename = root+'Flickr8k_text/Flickr_8k.trainImages.txt'
train = load_set(filename)
print('Dataset: %d' % len(train))
# load clean descriptions for train
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))

# load photo features for train using pkl file
train_features = load_photo_features('features.pkl', train)
print('Photos: train=%d' % len(train_features))

# prepare tokenizer for train descriptions
tokenizer = create_tokenizer(train_descriptions)
# save the tokenizer
dump(tokenizer, open('tokenizer.pkl', 'wb'))

vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length of train description
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)

# define the model
model = define_model(vocab_size, max_length)
# train the model, run epochs manually and save after each epoch
epochs = 5
steps = len(train_descriptions)
for i in range(epochs):
	# create the data generator
	generator = data_generator(train_descriptions, train_features, tokenizer, max_length, vocab_size)
	# fit for one epoch and verbose 1
	model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
	# save model
	model.save('model_' + str(i) + '.h5')
# Out:
# Dataset: 6000
# Descriptions: train=6000
# Photos: train=6000
# Vocabulary Size: 7579
# Description Length: 34
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 34)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 4096)]       0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 34, 256)      1940224     input_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 4096)         0           input_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 34, 256)      0           embedding[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          1048832     dropout[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 256)          525312      dropout_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256)          0           dense[0][0]
#                                                                  lstm[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          131584      add[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 7579)         3888027     dense_1[0][0]
# ==================================================================================================
# Total params: 7,533,979
# Trainable params: 7,533,979
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From <ipython-input-17-24e5444bd7ca>:84: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# 6000/6000 [==============================] - 618s 103ms/step - loss: 4.6760
# 6000/6000 [==============================] - 605s 101ms/step - loss: 3.9140
# 6000/6000 [==============================] - 602s 100ms/step - loss: 3.6617
# 6000/6000 [==============================] - 595s 99ms/step - loss: 3.4979
# 6000/6000 [==============================] - 604s 101ms/step - loss: 3.3857

# %% [markdown]
# # 5. Evaluate Model [2 Marks]

# %%
from numpy import argmax
from nltk.translate.bleu_score import corpus_bleu

def max_length(descriptions):
	# Convert descriptions to lines
	lines = to_lines(descriptions)
	return max(len(d.split()) for d in lines)
 
# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate a description for an image
def generate_desc(model, tokenizer, photo, max_length):
	# seed the generation process
	in_text = 'startseq'
	# iterate over the whole length of the sequence
	for i in range(max_length):
		# integer encode input sequence using texts_to_sequences (consider first element)
		sequence = tokenizer.texts_to_sequences([in_text])[0]
		# pad sequence for maxlength
		sequence = pad_sequences([sequence], maxlen=max_length)
		# predict next word using both photo and sequence
		yhat = model.predict([photo,sequence], verbose=0)
		# convert probability to integer
		yhat = argmax(yhat)
		# map integer to word
		word = word_for_id(yhat, tokenizer)
		# stop if we cannot map the word
		if word is None:
			break
		# append as input for generating the next word
		in_text += ' ' + word
		# stop if we predict the end of the sequence
		if word == 'endseq':
			break
	return in_text

# evaluate the skill of the model
def evaluate_model(model, descriptions, photos, tokenizer, max_length):
	# assign empty lists
	actual, predicted = list(), list()
	# step over the whole set
	for key, desc_list in descriptions.items():
		# generate description
		yhat = generate_desc(model, tokenizer, photos[key], max_length)
		# store actual and predicted
		references = [d.split() for d in desc_list]
		actual.append(references)
		predicted.append(yhat.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# prepare tokenizer on train set

# load training dataset (6K)
filename = root+'Flickr8k_text/Flickr_8k.trainImages.txt'
train = load_set(filename)
print('Dataset: %d' % len(train))
# load clean descriptions for train
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# prepare tokenizer for train descriptions
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)

# prepare test set

# load test set
filename = root+'Flickr8k_text/Flickr_8k.testImages.txt'
test = load_set(filename)
print('Dataset: %d' % len(test))
# load clean descriptions for test
test_descriptions = load_clean_descriptions('descriptions.txt', test)
print('Descriptions: test=%d' % len(test_descriptions))
# load photo features for test 
test_features = load_photo_features('features.pkl', test)
print('Photos: test=%d' % len(test_features))

# load the model
filename = 'model_1.h5'
model = load_model(filename)
# evaluate model
#####
evaluate_model(model, test_descriptions, test_features, tokenizer, max_length)
# Out:
# Dataset: 6000
# Descriptions: train=6000
# Vocabulary Size: 7579
# Description Length: 34
# Dataset: 1000
# Descriptions: test=1000

# %% [markdown]
# # 6. Generate new captions [1 Mark]

# %%
# extract features from each image in the directory
def extract_features(filename):
	# load the VGG16 model
	model = VGG16()
	# re-structure the model by removing the last layer
	#####
	model.layers.pop()
	model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
	# load the image
	image = load_img(filename, target_size=(224, 224))
	# convert the image pixels to a numpy array
	image = img_to_array(image)
	# reshape data for the model
	image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
	# preprocess the image for the VGG model
	image = preprocess_input(image)
	# get features (output of the model for the image)
	feature = model.predict(image, verbose=0)
	return feature

# load the tokenizer
tokenizer = load(open('tokenizer.pkl', 'rb'))
# pre-define the max sequence length (from training)
max_length = 34
# load the model
model = load_model('model_4.h5')
# load and prepare your own image to generate the caption
photo = extract_features('FootballMatch.jpg')   
# generate description
description = generate_desc(model, tokenizer, photo, max_length)
# provide your image file name 
from IPython.display import Image
Image(filename='FootballMatch.jpg')
print(description)
# Out:
# startseq two men are playing soccer on the grass endseq
